# %%
import json
with open('features.json') as featureFile:
    features = json.load(featureFile)

# %%
allFeatures = []
allFeatures = allFeatures+features['call_feature']['function'] + features['call_feature']['call_file'] + features['registry_feature'] + features['file_feature']['file']+features['file_feature']['directory'] + features['misc_feature']['misc'] + features['misc_feature']['com_sign']

# %%
allFeatures = allFeatures + ['malicious']

# %%
numFeatures = len(allFeatures)

# %%
numFiles = 45

# %%
def extractVirusFeature(virusStr):

# %%
for fileNum in range(numFiles):
            
    for feature in allFeatures:

# %%
with open('0.txt') as f:
    virusStr = f.read()

# %%
viruses = virusStr.split(' \n')

# %%
viruses
# Out:
# ['0.0740740740741 0:3 19:134 22:31 24:12 27:19 34:24 36:2 50:7 52:384 55:11 64:1 66:4 67:78 71:109 80:33 84:12 87:3 88:58 90:1 100:17 107:132 115:30 121:105 141:95 151:45 160:1 165:13 177:1 178:4 181:1 193:12 197:1 198:3 203:455 209:1 225:7 230:4 231:12 232:2 238:4 240:17 245:30 354:61 355:96 357:6 359:4 361:2 363:1 368:2 369:2 370:1',
#  '0.684210526316 19:14 20:2 24:2 27:2 34:1 36:791 45:5084 47:2 50:5 52:7 57:3 61:55 62:1 67:1 68:51 71:54 80:5085 84:5 87:2 93:2 100:1 104:3 107:67 109:1 111:1 115:3 121:65 123:1 128:3 129:1 132:3 140:2 141:2 142:1 151:9 154:789 160:3 169:2 174:2 186:1 190:1 198:1 203:8 209:4 230:1 232:3 236:3 240:1 245:1 353:1 354:7 355:54 357:2 362:2 364:1 367:1 368:1 369:3 370:2 422:1 469:1',
#  '0.814814814815 19:6 24:7 34:4 36:1 52:7 61:3 67:6 68:1 71:2 84:14 87:3 93:1 100:6 107:21 110:1 115:18 121:8 127:3 132:3 141:4 151:1691 154:1 178:1 186:1 193:1 198:5 203:21 209:5 225:2 232:5 245:5 354:13 355:11 357:3 359:1 360:3 362:1 364:1 369:2 370:1 391:1',
# ...
